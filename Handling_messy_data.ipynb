# %%
#Task1 — Clean the Data

import pandas as pd
import numpy as np

df = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 2, 5],
    'age':         [25, np.nan, 35, np.nan, np.nan, 40],
    'city':        ['Mumbai', 'Delhi', np.nan, 'Mumbai', 'Delhi', np.nan],
    'gender':      ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'annual_income': [40000, 80000, 60000, 120000, 80000, 95000]
})

df["age"]=df["age"].fillna(df["age"].median())
df["city"]=df["city"].fillna(df["city"].mode()[0])

df.drop_duplicates(subset=["customer_id"],inplace=True)

df

# %%
#Task2 — Encode Categorical Columns

from sklearn.preprocessing import LabelEncoder

df=pd.get_dummies(df,columns=["city"])

le=LabelEncoder()
df["gender"]=le.fit_transform(df["gender"])

df

# %%
#Task3 Min-Max Scaling

from sklearn.preprocessing import MinMaxScaler

scaler_min_max=MinMaxScaler()
df[["age","annual_income"]]=scaler_min_max.fit_transform(df[["age","annual_income"]])

df

# %%
#Task3 Standardisation or Z-Score Scaling

from sklearn.preprocessing import StandardScaler

scaler_std=StandardScaler()
df[["age","annual_income"]]=scaler_std.fit_transform(df[["age","annual_income"]])

df
